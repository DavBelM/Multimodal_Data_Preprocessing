# %% [markdown]
# # Task 1: Data Merge and Exploratory Data Analysis
#
# **Team Members:** Mitali, Blessing, Liliane, Mwai
#
# **Objective:**
# - Load customer_social_profiles and customer_transactions datasets
# - Perform comprehensive EDA
# - Clean and preprocess data
# - Merge datasets with justified logic
# - Engineer features for product prediction
# - Save merged dataset for modeling

# %% [markdown]
# ## 1. Import Libraries

# %%
# Data manipulation
import pandas as pd
import numpy as np

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Warnings
import warnings
warnings.filterwarnings('ignore')

# Display settings
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# Plotting style
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)

print("✅ Libraries imported successfully!")

# %% [markdown]
# ## 2. Load Datasets
#
# **Note:** Place the CSV files in `../data/raw/` directory before running this cell.

# %%
# Load datasets
social_df = pd.read_csv('../data/raw/customer_social_profiles.csv')
transactions_df = pd.read_csv('../data/raw/customer_transactions.csv')

print(f"Social Profiles Shape: {social_df.shape}")
print(f"Transactions Shape: {transactions_df.shape}")
print("\n✅ Datasets loaded successfully!")

# %% [markdown]
# ## 3. Exploratory Data Analysis (EDA)
#
# ### 3.1 Social Profiles Dataset

# %%
# Display first few rows
print("📊 First 5 rows of Social Profiles:")
display(social_df.head())

# Dataset info
print("\n📋 Dataset Info:")
social_df.info()

# Summary statistics
print("\n📈 Summary Statistics:")
display(social_df.describe())

# %%
# Check for missing values
print("🔍 Missing Values in Social Profiles:")
missing_social = social_df.isnull().sum()
missing_social_pct = (missing_social / len(social_df)) * 100
missing_info = pd.DataFrame({
    'Missing Count': missing_social,
    'Percentage': missing_social_pct
})
display(missing_info[missing_info['Missing Count'] > 0])

# Check for duplicates
print(f"\n🔄 Duplicate Rows: {social_df.duplicated().sum()}")

# %% [markdown]
# ### 3.2 Transactions Dataset

# %%
# Display first few rows
print("📊 First 5 rows of Transactions:")
display(transactions_df.head())

# Dataset info
print("\n📋 Dataset Info:")
transactions_df.info()

# Summary statistics
print("\n📈 Summary Statistics:")
display(transactions_df.describe())

# %%
# Check for missing values
print("🔍 Missing Values in Transactions:")
missing_trans = transactions_df.isnull().sum()
missing_trans_pct = (missing_trans / len(transactions_df)) * 100
missing_info = pd.DataFrame({
    'Missing Count': missing_trans,
    'Percentage': missing_trans_pct
})
display(missing_info[missing_info['Missing Count'] > 0])

# Check for duplicates
print(f"\n🔄 Duplicate Rows: {transactions_df.duplicated().sum()}")

# %% [markdown]
# ### 3.3 Visualizations
#
# **Requirement:** Create at least 3 labeled plots showing distributions, outliers, and correlations.

# %%
# Plot 1: Distribution of numerical features (Social Profiles)
# TODO: Identify numerical columns and plot their distributions

# Example:
# fig, axes = plt.subplots(2, 2, figsize=(15, 10))
# social_df['column_name'].hist(ax=axes[0,0], bins=30)
# axes[0,0].set_title('Distribution of Column Name')
# axes[0,0].set_xlabel('Column Name')
# axes[0,0].set_ylabel('Frequency')
# plt.tight_layout()
# plt.show()

print("📊 TODO: Add distribution plots")

# %%
# Plot 2: Box plots to detect outliers
# TODO: Create box plots for numerical features

print("📦 TODO: Add box plots for outlier detection")

# %%
# Plot 3: Correlation heatmap
# TODO: Create correlation matrix heatmap

# Example:
# correlation_matrix = social_df.select_dtypes(include=[np.number]).corr()
# plt.figure(figsize=(10, 8))
# sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0)
# plt.title('Correlation Heatmap - Social Profiles')
# plt.tight_layout()
# plt.show()

print("🔥 TODO: Add correlation heatmap")

# %% [markdown]
# ## 4. Data Cleaning
#
# ### 4.1 Handle Missing Values

# %%
# TODO: Implement missing value handling strategy
# Options: drop, fill with mean/median/mode, forward fill, etc.

# Example:
# social_df['column_name'].fillna(social_df['column_name'].mean(), inplace=True)

print("🧹 TODO: Handle missing values")

# %% [markdown]
# ### 4.2 Handle Duplicates

# %%
# Remove duplicates if any
social_df_clean = social_df.drop_duplicates()
transactions_df_clean = transactions_df.drop_duplicates()

print(f"Social Profiles - Rows removed: {len(social_df) - len(social_df_clean)}")
print(f"Transactions - Rows removed: {len(transactions_df) - len(transactions_df_clean)}")

# %% [markdown]
# ### 4.3 Fix Data Types

# %%
# TODO: Convert columns to appropriate data types
# Example: dates, categorical variables, etc.

# Example:
# transactions_df_clean['date_column'] = pd.to_datetime(transactions_df_clean['date_column'])

print("🔧 TODO: Fix data types")

# %% [markdown]
# ## 5. Data Merge
#
# ### 5.1 Identify Join Key
#
# **TODO:** Identify the common column(s) between both datasets to perform the merge.
# **Justification:** Explain why this join key makes sense for our product recommendation system.

# %%
# Inspect potential join keys
print("Social Profiles Columns:")
print(social_df_clean.columns.tolist())
print("\nTransactions Columns:")
print(transactions_df_clean.columns.tolist())

# TODO: Identify the join key (e.g., customer_id, user_id, etc.)

# %% [markdown]
# ### 5.2 Perform Merge

# %%
# TODO: Merge datasets
# Choose appropriate join type: inner, left, right, outer

# Example:
# merged_df = pd.merge(
#     social_df_clean,
#     transactions_df_clean,
#     on='customer_id',  # or appropriate key
#     how='inner'  # or left/right/outer
# )

# print(f"\nMerged Dataset Shape: {merged_df.shape}")
# display(merged_df.head())

print("🔗 TODO: Perform merge operation")

# %% [markdown]
# ### 5.3 Validate Merge

# %%
# TODO: Validate the merge
# Check for unexpected nulls, duplicates, or data loss

# Example:
# print("Missing values after merge:")
# print(merged_df.isnull().sum())
# print(f"\nDuplicates: {merged_df.duplicated().sum()}")

print("✅ TODO: Validate merge results")

# %% [markdown]
# ## 6. Feature Engineering
#
# Create new features that might improve product recommendation model.

# %%
# TODO: Engineer features
# Examples:
# - Total spending per customer
# - Average transaction value
# - Purchase frequency
# - Days since last purchase
# - Product category preferences
# - Engagement metrics from social profiles

print("🔨 TODO: Create engineered features")

# %% [markdown]
# ## 7. Target Variable
#
# Identify or create the target variable for product recommendation.

# %%
# TODO: Define target variable
# This could be:
# - Product category
# - Next product to purchase
# - Product preference score

print("🎯 TODO: Define target variable for product recommendation")

# %% [markdown]
# ## 8. Save Processed Dataset

# %%
# TODO: Save merged dataset
# merged_df.to_csv('../data/processed/merged_customer_data.csv', index=False)
# print("✅ Merged dataset saved to: data/processed/merged_customer_data.csv")

print("💾 TODO: Save processed dataset")

# %% [markdown]
# ## 9. Summary
#
# **TODO:** Document key findings and decisions:
#
# 1. **Data Quality Issues Found:**
#    -
#
# 2. **Merge Strategy & Justification:**
#    -
#
# 3. **Feature Engineering Decisions:**
#    -
#
# 4. **Next Steps:**
#    - Collect image and audio data
#    - Process multimodal features
#    - Train models
